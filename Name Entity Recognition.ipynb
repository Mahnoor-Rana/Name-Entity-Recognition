# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk import word_tokenize
from tqdm import tqdm

# %%
data = pd.read_csv('NER dataset.csv')
data.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
tags = list(set(data.POS.values))
tags
# Out:
# ['VBZ',
#  'VB',
#  'WP',
#  'JJ',
#  ';',
#  'NNS',
#  'WRB',
#  'VBP',
#  'EX',
#  ',',
#  'RRB',
#  'FW',
#  'RBS',
#  'WDT',
#  'RBR',
#  'JJS',
#  'MD',
#  'UH',
#  'PDT',
#  'NNP',
#  'PRP',
#  'CC',
#  'CD',
#  'JJR',
#  'RP',
#  'NNPS',
#  '.',
#  ':',
#  'VBG',
#  'RB',
#  'LRB',
#  'VBN',
#  'NN',
#  'WP$',
#  'TO',
#  'IN',
#  'POS',
#  'DT',
#  'PRP$',
#  'VBD',
#  '``',
#  '$']

# %% [markdown]
# ## Dictionary

# %%
words = list(set(data.Word.values))
words
# Out:
# ['resolved',
#  'U.N.-protected',
#  'Terry',
#  'popular',
#  'reconstruct',
#  'colder-than-usual',
#  'Jutarnji',
#  'Monkey',
#  'vents',
#  'Cloud',
#  'mosquito',
#  'reopens',
#  'disrupting',
#  'Istanbul',
#  'consulted',
#  'Daughter',
#  'seems',
#  'Ventures',
#  'Vavuniya',
#  '3,348',
#  'Angolan',
#  'Volcanic',
#  '300-million-dollar',
#  '159',
#  'desire',
#  'Gachechiladze',
#  'caved',
#  'conference',
#  'soil',
#  'reputation',
#  'bind',
#  'Reduction',
#  'cyber',
#  'Envoy',
#  'Bernard',
#  'serpent',
#  'suppliers',
#  'oxygen',
#  'practicing',
#  'isolation',
#  'big',
#  'chapel',
#  'eChoupal',
#  'Mattoo',
#  '60-kilometer',
#  'mid-to-late',
#  'Yushu',
#  'neon',
#  'exchange-rate',
#  'Chaib',
#  'mimics',
#  'narrated',
#  'applicants',
#  'inconvenient',
#  'Many',
#  'Srinigar',
#  'inefficiencies',
#  'student-led',
#  'notable',
#  'headlines',
#  'Boedihardjo',
#  'IRAQ-POVERTY',
#  'Patience',
#  'actor-turned-musician',
#  'Schearf',
#  'Manipur',
#  'well-developed',
#  'Busta',
#  'softer',
#  'wheel',
#  'Antwerp',
#  'Ehud',
#  'boat',
#  'two-man',
#  'geothermal',
#  'Abdalla',
#  'unaffiliated',
#  'NAM',
#  'Qaida-linked',
#  'clinching',
#  'sheeting',
#  'Hydrographic',
#  'el-Zahraa',
#  'Guardsmen',
#  'Challengerspace',
#  'slowed',
#  'aggravated',
#  'sunk',
#  '130-thousand',
#  'Belet',
#  'Hazem',
#  'Endeavouron',
#  'stampede',
#  'escalated',
#  'A&M',
#  'manipulated',
#  'cathedral',
#  'whereby',
#  'rice-growing',
#  'militarist',
#  'Gael',
#  'clamor',
#  'packaging',
#  'dispose',
#  'burying',
#  '2018',
#  'Railroad',
#  '1500s',
#  'Seiken',
#  'Abu',
#  'Occasional',
#  'poses',
#  'Sudeten',
#  'remedy',
#  'welfare-dependent',
#  'inconsistent',
#  '1,600',
#  'Georgy',
#  'politically-motivated',
#  'demographer',
#  'double-bombing',
#  'enact',
#  'H',
#  'unconsciousness',
#  'granddaughter',
#  'jailings',
#  'McAuliffe',
#  'Moqtada',
#  'Miyazaki',
#  'Bernanke',
#  'Inauguration',
#  'treat',
#  'extolling',
#  '2022',
#  'authenticate',
#  'biennial',
#  'Coordinating',
#  'mention',
#  'certify',
#  'Grimmette',
#  'biologist',
#  'Reader',
#  'Nicolae',
#  'finishing',
#  'Stem',
#  'Bursting',
#  'Lak',
#  'U.S.-Russian',
#  'staffing',
#  'guards',
#  'diplomats',
#  'Tzipi',
#  'hard-line',
#  'Amrullah',
#  'Resting',
#  'publicly',
#  'group',
#  'Preparations',
#  'quake-stricken',
#  'siege',
#  'Longer-term',
#  'razor',
#  'Vavi',
#  'fourth-busiest',
#  'ex-girlfriend',
#  'Resistance',
#  'continuation',
#  'S&P',
#  'picked',
#  '65',
#  'squad',
#  'agreements',
#  'acknowledged',
#  'Jing',
#  'Nabeel',
#  'Annan',
#  'pre-paid',
#  'Diplomacy',
#  'helmets',
#  'Explosive',
#  'Dakar',
#  'SAMBI',
#  'Osnabrueck',
#  'Chirac',
#  'ESTRADA',
#  'ex-president',
#  'Flanders',
#  'Taj',
#  'temporarily',
#  'Statoil',
#  'impassable',
#  'governors',
#  'Hofstad',
#  'Warsaw',
#  'Kian',
#  'touts',
#  'appreciate',
#  'Shota',
#  'emission',
#  'tourism-driven',
#  'one-child',
#  'out',
#  'mbalax',
#  'accommodations',
#  'Kirkuk',
#  'Libyan',
#  'Al-Anbar',
#  '137',
#  'Mouknass',
#  'sums',
#  'Lakshman',
#  'Gibbs',
#  'Zvarych',
#  'inhabitants',
#  '6,10,000',
#  'rites',
#  'celestial',
#  'colonize',
#  'PIGEON',
#  'alarming',
#  'fatwa',
#  'Panmunjom',
#  'apparent',
#  'peasants',
#  'Bangladeshis',
#  'Bangalore',
#  'sacred',
#  "Ba'th",
#  'with',
#  'Nearby',
#  'Drinan',
#  'Farraj',
#  'Industries',
#  'Eduardo',
#  're-invested',
#  'dose',
#  'Search',
#  'Hailu',
#  'URIBE',
#  'males',
#  'obligates',
#  'Narsingh',
#  'Ayodhya',
#  'hidden',
#  'Kirk',
#  'Saddamists',
#  'serenaded',
#  'mid-20th',
#  'mishandling',
#  'Shamsbari',
#  'rushed',
#  'Jihad',
#  '220-kilogram',
#  'stranger',
#  'several',
#  'Ferrero',
#  'Fund-Global',
#  'dismissing',
#  'Basayev',
#  'expired',
#  'intuitive',
#  'antics',
#  'Kwazulu-Natal',
#  'cote',
#  'il',
#  'Salas',
#  'minimize',
#  'force',
#  'centrally-planned',
#  'College',
#  'Biak',
#  'Arts',
#  'humiliation',
#  'Partridges',
#  'four-million',
#  'Venice',
#  'CORREA',
#  'Oumar',
#  '522',
#  'flooding',
#  'Fox',
#  'Comoros',
#  'dusk',
#  'fill',
#  'Afghanis',
#  'greatly',
#  'invested',
#  'repealed',
#  'recognizing',
#  'Messages',
#  'varies',
#  'Lahore',
#  'headlights',
#  'raiding',
#  'Namibian',
#  'Coldplay',
#  'fine-tuning',
#  'Gregg',
#  'MacKay',
#  'State-designate',
#  '1609',
#  'spirit',
#  'energetic',
#  'disinformation',
#  'Toure',
#  'McCartney',
#  'nationalize',
#  "N'Zerekore",
#  'defection',
#  'Posht-e-Rud',
#  'Post',
#  'Cavalese',
#  'remnants',
#  'Construction',
#  'Six-country',
#  'insidious',
#  'Duluth',
#  'rides',
#  'fenced',
#  'jobless',
#  "Pe'at",
#  'Takhar',
#  'Am',
#  'Otunbayeva',
#  'Wolde-Michael',
#  'Dawei-Ye',
#  'scold',
#  'Shihab',
#  'shores',
#  '02-Jun',
#  'Quarter',
#  'Creator',
#  'stumbled',
#  'disrepair',
#  'Suspected',
#  '8.8-magnitude',
#  'cohesion',
#  'encounters',
#  'senator',
#  'accurate',
#  'decathlon',
#  'Caribbean',
#  'Persson',
#  'four-decade',
#  'serve',
#  'pence',
#  'newly-formed',
#  'Horizonte',
#  'organic',
#  'disbursement',
#  'exacted',
#  'underwent',
#  'Jericho',
#  'Blackwater',
#  'Kofi',
#  'hectares',
#  'Ongoing',
#  'terminate',
#  'charming',
#  'asylum',
#  'altitude',
#  'Abdel-Rahman',
#  'Tarmohammed',
#  'aggressively',
#  'Herzegovina',
#  'embolden',
#  'Queen',
#  'Al-Jazeera',
#  'thought',
#  'bag',
#  'participated',
#  'reassured',
#  'camouflage',
#  'al-Tamimi',
#  'unimaginable',
#  'licensing',
#  'Malaysian-led',
#  'afforded',
#  '22.4',
#  'Week',
#  'Bolt',
#  'Eindhoven',
#  'SAVIMBI',
#  'Mangwana',
#  'Chacon',
#  '170',
#  'Ranch',
#  'Mwai',
#  'murderers',
#  'Yurchikhin',
#  'Nikolas',
#  'narrowing',
#  'Town',
#  'Serra',
#  'arteries',
#  'non-functional',
#  'below-average',
#  'acrobatic',
#  'Svinarov',
#  'customs',
#  'prayed',
#  'aided',
#  'Milan',
#  'editor-in-chief',
#  'Ul-Islam',
#  'Coffee',
#  'submitting',
#  'affiliated',
#  'anchor',
#  'Samho',
#  'cancer',
#  'refloating',
#  '915',
#  'Alaska',
#  'insistence',
#  'Hycamtin',
#  '9.625',
#  'Arthurs',
#  'Scheduled',
#  'al-Youm',
#  'avenging',
#  'inconclusive',
#  'wonder',
#  'Interahamwe',
#  'Soviet-sponsored',
#  'prosecuted',
#  '20-meter',
#  'Liege',
#  'Sylvester',
#  'Yalcinkaya',
#  'nullify',
#  '191',
#  'civilian',
#  '01-Jan',
#  'Greens',
#  'Ranger',
#  'treasures',
#  'Prithvi',
#  'bases',
#  'establishes',
#  'Parkinson',
#  'Uzair',
#  'tension',
#  'winner',
#  '46-nation',
#  'Ford',
#  '720',
#  'whatever',
#  'Sarna',
#  'wrongfully',
#  '&',
#  'TRYGGVASON',
#  'outlining',
#  'tarnished',
#  'credentials',
#  'thirty',
#  'Barbey',
#  '1,254',
#  'Economics',
#  'abusive',
#  'defaulted',
#  'accepts',
#  'toothless',
#  'skyscraper',
#  'Hanun',
#  'canned',
#  'southwest',
#  'Kurzban',
#  'responsibly',
#  'unmonitored',
#  'Soldaten',
#  'premises',
#  'indicating',
#  '1930s',
#  'Seyoum',
#  'policy',
#  'carries',
#  'Pro-Russian',
#  'explorers',
#  'meningitis',
#  'Verde',
#  'Kenneth',
#  'strikingly',
#  'mauled',
#  'stoning',
#  'joined',
#  'wiped',
#  'unfunded',
#  'rarely',
#  '28.25',
#  'suicide-bomber',
#  'Rescuers',
#  'students',
#  'avarice',
#  'Kimi',
#  'classified',
#  'patents',
#  'Afars',
#  'contacting',
#  'counterproductive',
#  'Adding',
#  'riot',
#  'unwavering',
#  'eight-year-old',
#  'Mashjid',
#  'transports',
#  'Gong',
#  'outsourcing',
#  'Europe-wide',
#  'corrected',
#  'Khaisor',
#  'difficulties',
#  'siphoning',
#  'habitations',
#  'necks',
#  'conglomerate',
#  'applies',
#  'insisting',
#  'Islam',
#  'mid-December',
#  'lambasted',
#  'Exiles',
#  'impede',
#  '259',
#  'improved',
#  'Tikrit',
#  'ARISTIDE',
#  'corrosion',
#  'above',
#  'Flemings',
#  'transitioning',
#  'immensely',
#  'black-clad',
#  'Viktor',
#  'Nicholas',
#  'Drops',
#  'repatriation',
#  'BBC',
#  'Self-Defense',
#  'bias',
#  'Basra',
#  'reversal',
#  'Miltzow',
#  '367',
#  'Schlegel',
#  'auditing',
#  'Sindh',
#  'Rechnitzer',
#  'militarily',
#  'Committee',
#  'Mohannad',
#  'administering',
#  'arriving',
#  'Damascus',
#  'Rish',
#  'Abdel',
#  'worm',
#  'Egypt-Gaza',
#  'director-general',
#  'tenure',
#  "O'Hare",
#  'Chuprun',
#  'safer',
#  'Apr-46',
#  'stray',
#  '?',
#  'photograph',
#  'Settled',
#  'Strategic',
#  'Stockholm',
#  'Lukic',
#  'PODEMOS',
#  'paces',
#  'Gun',
#  'Ruhollah',
#  '90-year-old',
#  'hurled',
#  'lose',
#  '1,59,000',
#  'Nigerians',
#  'al-Hayam',
#  'suite',
#  'Koreb',
#  'seminary',
#  'applauding',
#  'Raich',
#  'scruple',
#  'Telecom',
#  'cafes',
#  'mansion',
#  'Slavic',
#  '122',
#  'vagaries',
#  'video-sharing',
#  'license',
#  'Burton',
#  '1278',
#  'Dragoljub',
#  'Telesur',
#  'debts',
#  'suffocated',
#  'admiration',
#  'curtains',
#  'Monaco',
#  'Sinai',
#  'TRAVELERS',
#  'arsenals',
#  'slightest',
#  'pets',
#  'pulled',
#  'graveyards',
#  'standard-of-living',
#  'Obrador',
#  'carrier',
#  'Made',
#  'Verizon',
#  'Budny',
#  'Austrian',
#  'vaccinators',
#  'limbs',
#  'stump',
#  'Dubbed',
#  'gala',
#  'oppressed',
#  'Napolitano',
#  'Kor',
#  'supervising',
#  'Gas',
#  'provided',
#  'multiply',
#  'Polish-Lithuanian',
#  'assailants',
#  'convention',
#  'Huda',
#  'accessed',
#  'nozzles',
#  'plane',
#  'Guangzhong',
#  'Silvestre',
#  'Tabare',
#  'goodwill',
#  'gaining',
#  'Homeowners',
#  'quarterly',
#  'toxicology',
#  'Kartli-Iberia',
#  'opened',
#  'Bids',
#  'reaped',
#  'rowing',
#  'GDP',
#  'bioethics',
#  'Garrigues',
#  'Sandy',
#  'Alizai',
#  'sulphur',
#  'Edwards',
#  '461',
#  '225',
#  'Na',
#  'codefendants',
#  'forecasters',
#  'Kenya',
#  'fourth-highest',
#  'Delgado',
#  'highest',
#  'occupy',
#  'weaker',
#  'Yanbu',
#  'cheeks',
#  'divorcing',
#  "N'Dour",
#  'Cargo',
#  'cooperation',
#  'peace-loving',
#  'Lion',
#  '4.55',
#  'Reid',
#  'starred',
#  'Christine',
#  'Safeguards',
#  'facing',
#  'rift',
#  'Retail',
#  'justice',
#  'Rowan',
#  'insurmountable',
#  '04-Jan',
#  'surrounding',
#  'jute',
#  'mockery',
#  'Iscuande',
#  'Daniele',
#  'shoreline',
#  'anti-flu',
#  'drawings',
#  'Southern',
#  'grow',
#  'Saleh',
#  'meet',
#  'Destiny',
#  'Borjomi',
#  'Ahronoth',
#  'retained',
#  'farfetched',
#  'front-page',
#  'Bajur',
#  'faltering',
#  'weight-loss',
#  'contracts',
#  'Regiment',
#  'Scorpion',
#  'disparities',
#  '598-seat',
#  'theatergoers',
#  'necessitate',
#  'Paynesville',
#  'fast-food',
#  'lest',
#  'blindfolded',
#  'museums',
#  'portfolio',
#  'half',
#  '73,276',
#  'conductor',
#  'bouncing',
#  'Kouk',
#  'epidemiologists',
#  'interception',
#  'combining',
#  'Eritrea-Ethiopia',
#  'jersey',
#  'barge',
#  'strive',
#  'forestry',
#  'Iraq',
#  'Mehran',
#  'Gazprom',
#  'intensifying',
#  'lamented',
#  'auditors',
#  'Solis',
#  'necessities',
#  'USPI',
#  'consecutive',
#  'Malwiya',
#  'cassettes',
#  'uninsured',
#  'embedded',
#  'Ayyub',
#  'Mehlis',
#  'meets',
#  'News',
#  'stoves',
#  'Andry',
#  'Guard',
#  'possible',
#  'negotiator',
#  'Cameroon',
#  'reductions',
#  'Sakhalin-2',
#  'zoological',
#  'Dogg',
#  '370',
#  'militant-related',
#  'Fargo',
#  'parties',
#  'Poroshenko',
#  'R�sch',
#  'worries',
#  'jailhouse',
#  'Leif',
#  'Weddings',
#  'jog',
#  'informal',
#  'rid',
#  'skip',
#  'Afghani',
#  '4,10,000',
#  'Dizzy',
#  'Khaled',
#  'Nazran',
#  'unlawful',
#  'densely-populated',
#  'interviewer',
#  'bomb-proof',
#  'VanAllen',
#  'strategic',
#  'Frenchmen',
#  'Ana',
#  'Founding',
#  'ideal',
#  'replaced',
#  'Datapoint',
#  'controlled',
#  'Christians',
#  'Hispaniola',
#  'natives',
#  'ignore',
#  'Mainz',
#  'Rebecca',
#  'CRANES',
#  'compliments',
#  'capitalist',
#  'transition',
#  'generals',
#  'frequencies',
#  'al-Qawasmi',
#  'shrinks',
#  'activity',
#  'masterminding',
#  'tanker',
#  '11725',
#  'talked',
#  'random',
#  'meanwhile',
#  'lottery',
#  'statments',
#  'Novakatkan',
#  'equalized',
#  'Bengal',
#  'Surgeon',
#  'ecotourism',
#  '690',
#  'matched',
#  'penetrate',
#  'authenticity',
#  '243',
#  'Tomb',
#  'HARES',
#  'dependency',
#  'Lusaka',
#  'Kohlschreiber',
#  'Sgorbati',
#  'Wiig',
#  'burned',
#  'draws',
#  'forensic',
#  'Splendour',
#  'al-Aqsa',
#  '68.4',
#  'Indian-',
#  'Heinz',
#  'Tytler',
#  'edict',
#  'withered',
#  'Orenburg',
#  'inciting',
#  'peril',
#  'cylinders',
#  'handling',
#  'White',
#  'insulation',
#  'Ezzedin',
#  'spiraled',
#  'Producing',
#  'consular',
#  'Five',
#  'nullified',
#  'Sharon',
#  'opening-day',
#  'Walleye',
#  'knight',
#  'Chancellor',
#  'DC',
#  'unknowingly',
#  'fears',
#  'Sassou-Nguesso',
#  'nasal',
#  'U.S.-Iraqi',
#  'literate',
#  'Manmohan',
#  'Stubb',
#  'ambassador-at-large',
#  'directed',
#  'sees',
#  'weather',
#  'privilege',
#  'sprayed',
#  'rallying',
#  'Jersey',
#  'depleting',
#  'dubious',
#  'rabbis',
#  'NATO-Afghan',
#  'haves',
#  'Wise',
#  '53-year',
#  'Altria',
#  'affiliations',
#  'Bavarian',
#  'Ashfaq',
#  'wild-boar',
#  'Vukovar',
#  'pilgrims',
#  'Mayer',
#  'revere',
#  'fundraising',
#  'Finance',
#  'Hilda',
#  'Marta',
#  'Ketzer',
#  '215',
#  'Clinic',
#  'Years',
#  'Comprehensive',
#  'enterprising',
#  'GM',
#  '20th',
#  'doused',
#  'sunflower',
#  'Terrorist',
#  'Arap',
#  'Horobets',
#  'remainder',
#  'uneven',
#  'qualifiers',
#  'Kveta',
#  'mutating',
#  'Baby',
#  'DPRK',
#  'orphan',
#  'nationalized',
#  'reefs',
#  'two-part',
#  'credible',
#  'replenish',
#  'colors',
#  'accelerate',
#  'Razuri',
#  'wreck',
#  'Moroccan',
#  'Schwarzenburg',
#  'Gunsmoke',
#  'Pramoni',
#  'Mostafavi',
#  'Forty-one',
#  'collaboration',
#  'hopeful',
#  'Aghazadeh',
#  'conservationists',
#  'sews',
#  'reassuring',
#  'Wagner',
#  'Palestinian-Americans',
#  'Franklin',
#  'syphon',
#  'Camilo',
#  'ahead',
#  'roams',
#  'derive',
#  'fatigues',
#  'Musharraf',
#  'covers',
#  'doubt',
#  '8000',
#  '2.75',
#  'jet',
#  'Evgeni',
#  'loudspeakers',
#  'scheduled',
#  'precinct',
#  'el-Hadary',
#  'incumbent',
#  'shoved',
#  'Ataturk',
#  'sadly',
#  'Rolling',
#  'relate',
#  'halfway',
#  'Kountch�',
#  'Greg',
#  'Khursheed',
#  'charcoal',
#  'Marra',
#  'airport',
#  '5.7-kilometer',
#  'peregrine',
#  'master',
#  'Doug',
#  'tabloid',
#  'Votel',
#  'unbeaten',
#  'Sufi',
#  'anniversary',
#  'Srebrenica',
#  'adherence',
#  'wildly',
#  'candlelit',
#  'website',
#  'porpoises',
#  'functioning',
#  'being',
#  'Shevardnadze',
#  'subcontinent',
#  'Preventive',
#  'on',
#  '9.9',
#  '128-member',
#  'Tufail',
#  ...]

# %%
np.array(words[:20]).flatten()
# Out:
# array(['resolved', 'U.N.-protected', 'Terry', 'popular', 'reconstruct',
#        'colder-than-usual', 'Jutarnji', 'Monkey', 'vents', 'Cloud',
#        'mosquito', 'reopens', 'disrupting', 'Istanbul', 'consulted',
#        'Daughter', 'seems', 'Ventures', 'Vavuniya', '3,348'], dtype='<U17')

# %% [markdown]
# ## Adding Word dummy

# %%
# adding the word dummy to dictionary so that we can pad sentences
words.append('dummy')

# %% [markdown]
# ## Creating a class to read sentences

# %%
class read_sen():
    def __init__(self, data):
        self.data = data
        agg_func = lambda s : [(w,p,t) for w , p, t in zip(s['Word'].values.tolist(),
                                                          s['POS'].values.tolist(),
                                                          s['Tag'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]

# %%
sentences = read_sen(data).sentences
sentences
# Out:
# [[('Thousands', 'NNS', 'O')],
#  [('Iranian', 'JJ', 'B-gpe')],
#  [('Helicopter', 'NN', 'O')],
#  [('They', 'PRP', 'O')],
#  [('U.N.', 'NNP', 'B-geo')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('Some', 'DT', 'O')],
#  [('Aid', 'NNP', 'O')],
#  [('Lebanese', 'JJ', 'B-gpe')],
#  [('In', 'IN', 'O')],
#  [('One', 'CD', 'O')],
#  [('Lebanon', 'NNP', 'B-geo')],
#  [('Syria', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('Doctors', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Doctors', 'NNS', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Doctors', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('SpaceShipOne', 'NNP', 'B-art')],
#  [('To', 'TO', 'O')],
#  [('The', 'DT', 'O')],
#  [('Three', 'CD', 'O')],
#  [('The', 'DT', 'O')],
#  [('SpaceShipOne', 'NNP', 'B-art')],
#  [('North', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Most', 'JJS', 'O')],
#  [('Last', 'JJ', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Prime', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('An', 'DT', 'O')],
#  [('Both', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Nearly', 'RB', 'O')],
#  [('The', 'DT', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('Snoop', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('Afghan', 'JJ', 'B-gpe')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('But', 'CC', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('And', 'CC', 'O')],
#  [('For', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('Francois', 'NNP', 'B-per')],
#  [('In', 'IN', 'O')],
#  [('President', 'NNP', 'B-per')],
#  [('After', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('Those', 'DT', 'O')],
#  [('They', 'PRP', 'O')],
#  [('Burmese', 'JJ', 'B-gpe')],
#  [('In', 'IN', 'O')],
#  [('Global', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('That', 'DT', 'O')],
#  [('She', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Former', 'JJ', 'O')],
#  [('Opening', 'VBG', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Organizers', 'NNS', 'O')],
#  [('Expected', 'VBN', 'O')],
#  [('Peruvian', 'JJ', 'B-gpe')],
#  [('A', 'DT', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Garcia', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Since', 'IN', 'O')],
#  [('Either', 'CC', 'O')],
#  [('Chilean', 'JJ', 'B-gpe')],
#  [('Lucia', 'NNP', 'B-per')],
#  [('A', 'DT', 'O')],
#  [('If', 'IN', 'O')],
#  [('General', 'NNP', 'B-per')],
#  [('40', 'CD', 'O')],
#  [('The', 'DT', 'O')],
#  [('His', 'PRP$', 'O')],
#  [('Rebel', 'NN', 'O')],
#  [('Zapatista', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('She', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('She', 'PRP', 'O')],
#  [('On', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('Representatives', 'NNS', 'O')],
#  [('In', 'IN', 'O')],
#  [('In', 'IN', 'O')],
#  [('There', 'EX', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('In', 'IN', 'O')],
#  [('Leading', 'VBG', 'O')],
#  [('The', 'DT', 'O')],
#  [('Their', 'PRP$', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('However', 'RB', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Microsoft', 'NNP', 'B-org')],
#  [('Donors', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Spain', 'NNP', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('Health', 'NN', 'O')],
#  [('More', 'JJR', 'O')],
#  [('Among', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Prosecutors', 'NNS', 'O')],
#  [('European', 'NNP', 'B-org')],
#  [('Chief', 'NNP', 'O')],
#  [('She', 'PRP', 'O')],
#  [('Ms.', 'NNP', 'B-per')],
#  [('Campaigning', 'VBG', 'O')],
#  [('But', 'CC', 'O')],
#  [('The', 'DT', 'O')],
#  [('An', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Afghan', 'JJ', 'B-gpe')],
#  [('In', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('Last', 'JJ', 'O')],
#  [('At', 'IN', 'O')],
#  [('U.S.', 'NNP', 'B-org')],
#  [('French', 'JJ', 'B-gpe')],
#  [('At', 'IN', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('One', 'CD', 'O')],
#  [('Four', 'CD', 'O')],
#  [('The', 'DT', 'O')],
#  [('An', 'DT', 'O')],
#  [('Yemen', 'NNP', 'B-org')],
#  [('Petroleum', 'NN', 'O')],
#  [('Yemen', 'NNP', 'B-org')],
#  [('In', 'IN', 'O')],
#  [('In', 'IN', 'O')],
#  [('Despite', 'IN', 'O')],
#  [('Singapore', 'NNP', 'B-org')],
#  [('It', 'PRP', 'O')],
#  [('Singapore', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Ruled', 'VBN', 'O')],
#  [('During', 'IN', 'O')],
#  [('His', 'PRP$', 'O')],
#  [('In', 'IN', 'O')],
#  [('As', 'IN', 'O')],
#  [('Subsistence', 'NNP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Timber', 'NNP', 'O')],
#  [('Important', 'JJ', 'O')],
#  [('Factional', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('Distribution', 'NN', 'O')],
#  [('Grants', 'NNS', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('When', 'WRB', 'O')],
#  [('Taking', 'VBG', 'O')],
#  [('THE', 'DT', 'O')],
#  [('They', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Then', 'RB', 'O')],
#  [('Georgian', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('Never', 'RB', 'O')],
#  [('Old', 'JJ', 'O')],
#  [('Nostalgia', 'NN', 'O')],
#  [('You', 'PRP', 'O')],
#  [('My', 'PRP$', 'O')],
#  [('He', 'PRP', 'O')],
#  [('After', 'IN', 'O')],
#  [('Advance', 'NNP', 'O')],
#  [('News', 'NNP', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('However', 'RB', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Former', 'JJ', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Sri', 'NNP', 'B-gpe')],
#  [('Officials', 'NNS', 'O')],
#  [('They', 'PRP', 'O')],
#  [('Government', 'NN', 'O')],
#  [('Thousands', 'NNS', 'O')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Tens', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('U.S.', 'NNP', 'B-geo')],
#  [('Earlier', 'RBR', 'O')],
#  [('It', 'PRP', 'O')],
#  [('Last', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Someone', 'DT', 'O')],
#  [('So', 'RB', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('That', 'DT', 'O')],
#  [('On', 'IN', 'O')],
#  [('VOA', 'NNP', 'B-org')],
#  [('A', 'DT', 'O')],
#  [('British', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('British', 'JJ', 'B-gpe')],
#  [('It', 'PRP', 'O')],
#  [('An', 'DT', 'O')],
#  [('Johnston', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('U.S', 'NNP', 'B-org')],
#  [('A', 'DT', 'O')],
#  [('Israel', 'NNP', 'B-geo')],
#  [('Venezuelan', 'JJ', 'B-gpe')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Venezuelan', 'JJ', 'B-gpe')],
#  [('A', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Overall', 'RB', 'O')],
#  [('In', 'IN', 'O')],
#  [('No', 'DT', 'O')],
#  [('More', 'JJR', 'O')],
#  [('European', 'JJ', 'O')],
#  [('U.S.', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('Ms.', 'NNP', 'B-per')],
#  [('South', 'JJ', 'O')],
#  [('She', 'PRP', 'O')],
#  [('She', 'PRP', 'O')],
#  [('At', 'IN', 'O')],
#  [('Indian', 'JJ', 'B-gpe')],
#  [('They', 'PRP', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('Indian', 'JJ', 'B-gpe')],
#  [('But', 'CC', 'O')],
#  [('The', 'DT', 'O')],
#  [('Hundreds', 'NNS', 'O')],
#  [('KFC', 'NNP', 'B-org')],
#  [('In', 'IN', 'O')],
#  [('But', 'CC', 'O')],
#  [('Rahimgul', 'NNP', 'B-per')],
#  [('Brian', 'NNP', 'B-per')],
#  [('Israel', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Earlier', 'RB', 'O')],
#  [('Foreign', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('Contracted', 'VBN', 'O')],
#  [('Although', 'IN', 'O')],
#  [('Investments', 'NNP', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('They', 'PRP', 'O')],
#  [('They', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Nepal', 'NNP', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Violence', 'NN', 'O')],
#  [('The', 'DT', 'O')],
#  [('More', 'JJR', 'O')],
#  [('U.S.', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('But', 'CC', 'O')],
#  [('Anti-Japanese', 'JJ', 'O')],
#  [('Speaking', 'VBG', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Last', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Some', 'DT', 'O')],
#  [('VOA', 'NNP', 'B-org')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('Venezuela', 'NNP', 'B-gpe')],
#  [('Media', 'NNS', 'O')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('An', 'DT', 'O')],
#  [('Qatar', 'NNP', 'B-geo')],
#  [('Thousands', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Although', 'IN', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('Defense', 'NN', 'O')],
#  [('Three', 'CD', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('Police', 'NNS', 'O')],
#  [('Hours', 'NNS', 'O')],
#  [('One', 'CD', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('On', 'IN', 'O')],
#  [('Afghan', 'JJ', 'B-gpe')],
#  [('A', 'DT', 'O')],
#  [('On', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Helmand', 'NNP', 'B-geo')],
#  [('Russia', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('Duma', 'NNP', 'B-geo')],
#  [('Moscow', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('Moscow', 'NNP', 'B-geo')],
#  [('Earlier', 'RBR', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Venezuela', 'NNP', 'B-gpe')],
#  [('Adult', 'JJ', 'O')],
#  [('A', 'DT', 'O')],
#  [('VOA', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Meanwhile', 'RB', 'O')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('Military', 'JJ', 'O')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('One', 'CD', 'O')],
#  [('Iran', 'NNP', 'B-geo')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('Elsewhere', 'RB', 'O')],
#  [('Separately', 'RB', 'O')],
#  [('U.N.', 'NNP', 'B-org')],
#  [('In', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('In', 'IN', 'O')],
#  [('Speaking', 'VBG', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('Their', 'PRP$', 'O')],
#  [('Egyptian', 'JJ', 'B-gpe')],
#  [('Egyptian', 'JJ', 'B-gpe')],
#  [('Authorities', 'NNS', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('U.S.', 'NNP', 'B-geo')],
#  [('A', 'DT', 'O')],
#  [('Economists', 'NNS', 'O')],
#  [('Employment', 'NN', 'O')],
#  [('Iran', 'NNP', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Venezuela', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('They', 'PRP', 'O')],
#  [('During', 'IN', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('Highly', 'RB', 'O')],
#  [('About', 'IN', 'O')],
#  [('There', 'EX', 'O')],
#  [('At', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('Nepal', 'NNP', 'B-gpe')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('They', 'PRP', 'O')],
#  [('Elsewhere', 'RB', 'O')],
#  [('The', 'DT', 'O')],
#  [('Straw', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('But', 'CC', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('Two', 'CD', 'O')],
#  [('One', 'CD', 'O')],
#  [('The', 'DT', 'O')],
#  [('VOA', 'NNP', 'B-org')],
#  [('Forensic', 'JJ', 'O')],
#  [('Eyewitnesses', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Bosnian', 'JJ', 'B-gpe')],
#  [('In', 'IN', 'O')],
#  [('They', 'PRP', 'O')],
#  [('Iranian', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Few', 'JJ', 'O')],
#  [('Thousands', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Top-seeded', 'JJ', 'O')],
#  [('President', 'NNP', 'B-per')],
#  [('Hewitt', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('But', 'CC', 'O')],
#  [('Unseeded', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('Pop', 'NN', 'O')],
#  [('On', 'IN', 'O')],
#  [('VOA', 'NNP', 'B-org')],
#  [('Saturday', 'NNP', 'B-tim')],
#  [('Police', 'NNS', 'O')],
#  [('Italian', 'JJ', 'B-gpe')],
#  [('While', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('He', 'PRP', 'O')],
#  [('But', 'CC', 'O')],
#  [('A', 'DT', 'O')],
#  [('Special', 'JJ', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('At', 'IN', 'O')],
#  [('Hours', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Soldiers', 'NNS', 'O')],
#  [('An', 'DT', 'O')],
#  [('Muhammad', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Many', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('President', 'NNP', 'B-per')],
#  [('Oil', 'NN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('They', 'PRP', 'O')],
#  [('Despite', 'IN', 'O')],
#  [('Earlier', 'RBR', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('At', 'IN', 'O')],
#  [('Congress', 'NNP', 'B-org')],
#  [('In', 'IN', 'O')],
#  [('Taiwan', 'NNP', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('China', 'NNP', 'B-geo')],
#  [('China', 'NNP', 'B-geo')],
#  [('Diplomats', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('They', 'PRP', 'O')],
#  [('Hurricane', 'NNP', 'B-nat')],
#  [('The', 'DT', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('On', 'IN', 'O')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('An', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Friday', 'NNP', 'B-tim')],
#  [('Unofficial', 'JJ', 'O')],
#  [('U.S.', 'NNP', 'B-geo')],
#  [('A', 'DT', 'O')],
#  [('Israel', 'NNP', 'B-geo')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [("Shi'ite", 'NNP', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('But', 'CC', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Based', 'VBN', 'O')],
#  [('Of', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Residents', 'NNS', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('South', 'NNP', 'B-geo')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('About', 'IN', 'O')],
#  [('Many', 'JJ', 'O')],
#  [('Hussein', 'NNP', 'B-per')],
#  [('Egyptian', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('At', 'IN', 'O')],
#  [('Building', 'NN', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Thousands', 'NNS', 'O')],
#  [('Both', 'DT', 'O')],
#  [('Some', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('Airport', 'NNP', 'O')],
#  [('But', 'CC', 'O')],
#  [('Many', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('State', 'NNP', 'B-org')],
#  [('He', 'PRP', 'O')],
#  [('Skubiszewski', 'NNP', 'B-org')],
#  [('No', 'DT', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('He', 'PRP', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Skubiszewski', 'NNP', 'B-org')],
#  [('Scientists', 'NNS', 'O')],
#  [('Two', 'CD', 'O')],
#  [('Paul', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Witnesses', 'NNS', 'O')],
#  [('Sudan', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Russian', 'JJ', 'B-gpe')],
#  [('Opposition', 'NN', 'O')],
#  [('They', 'PRP', 'O')],
#  [('News', 'NNP', 'O')],
#  [('She', 'PRP', 'O')],
#  [('She', 'PRP', 'O')],
#  [('Elsewhere', 'RB', 'O')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('At', 'IN', 'O')],
#  [('Local', 'JJ', 'O')],
#  [('At', 'IN', 'O')],
#  [('Pakistani', 'JJ', 'B-gpe')],
#  [('Closer', 'NNP', 'O')],
#  [('Earlier', 'RBR', 'O')],
#  [('The', 'DT', 'O')],
#  [('Hundreds', 'NNS', 'O')],
#  [('It', 'PRP', 'O')],
#  [('Protesters', 'NNP', 'O')],
#  [('They', 'PRP', 'O')],
#  [('Earlier', 'RB', 'O')],
#  [('Many', 'JJ', 'O')],
#  [('Pakistan', 'NNP', 'B-geo')],
#  [('Elsewhere', 'RB', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('Their', 'PRP$', 'O')],
#  [('A', 'DT', 'O')],
#  [('Military', 'JJ', 'O')],
#  [('A', 'DT', 'O')],
#  [('Army', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('She', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Burundi', 'NNP', 'B-geo')],
#  [('At', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Acting', 'VBG', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('A', 'DT', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('Despite', 'IN', 'O')],
#  [('A', 'DT', 'O')],
#  [('Ismael', 'NNP', 'B-per')],
#  [('Meanwhile', 'RB', 'O')],
#  [('In', 'IN', 'O')],
#  [('British', 'JJ', 'B-gpe')],
#  [('It', 'PRP', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Afghan', 'JJ', 'B-gpe')],
#  [('Officials', 'NNS', 'O')],
#  [('General', 'NNP', 'B-per')],
#  [('But', 'CC', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('A', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('Mahmoud', 'NNP', 'B-per')],
#  [('Iran', 'NNP', 'B-geo')],
#  [('He', 'PRP', 'O')],
#  [('In', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Earlier', 'RB', 'O')],
#  [('NATO', 'NNP', 'B-org')],
#  [('In', 'IN', 'O')],
#  [('NATO', 'NNP', 'B-org')],
#  [('NATO', 'NNP', 'B-org')],
#  [('Meanwhile', 'RB', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Thousands', 'NNS', 'O')],
#  [('Simonyi', 'NNP', 'B-per')],
#  [('At', 'IN', 'O')],
#  [('At', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('No', 'DT', 'O')],
#  [('But', 'CC', 'O')],
#  [('President', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Moscow', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('Nearby', 'RB', 'O')],
#  [('Also', 'RB', 'O')],
#  [('His', 'PRP$', 'O')],
#  [('Also', 'RB', 'O')],
#  [('That', 'DT', 'O')],
#  [('U.S.', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('On', 'IN', 'O')],
#  [('Palestinian', 'JJ', 'B-gpe')],
#  [('Two', 'CD', 'O')],
#  [('If', 'IN', 'O')],
#  [('That', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('An', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('More', 'JJR', 'O')],
#  [('The', 'DT', 'O')],
#  [('Haitian', 'JJ', 'B-gpe')],
#  [('President', 'NNP', 'B-per')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('In', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('During', 'IN', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('But', 'CC', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('But', 'CC', 'O')],
#  [('Many', 'JJ', 'O')],
#  [('Hong', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Earlier', 'RBR', 'O')],
#  [('The', 'DT', 'O')],
#  [('And', 'CC', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('Authorities', 'NNS', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('Sudanese', 'JJ', 'B-gpe')],
#  [('Authorities', 'NNS', 'O')],
#  [('Sudan', 'NNP', 'B-org')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Sudan', 'NNP', 'B-gpe')],
#  [('A', 'DT', 'O')],
#  [('Sotheby', 'NNP', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Beethoven', 'NNP', 'B-per')],
#  [('A', 'DT', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('They', 'PRP', 'O')],
#  [('Few', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('During', 'IN', 'O')],
#  [('Saddam', 'NNP', 'B-per')],
#  [('Australian', 'JJ', 'B-gpe')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('But', 'CC', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('State', 'NN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('On', 'IN', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('About', 'IN', 'O')],
#  [('Azeris', 'NNS', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('ETA', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('Though', 'IN', 'O')],
#  [('Peace', 'NN', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('Police', 'NNS', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Tensions', 'NNS', 'O')],
#  [('Iraqi', 'JJ', 'B-gpe')],
#  [('Violence', 'NN', 'O')],
#  [('Spanish', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('British', 'JJ', 'B-gpe')],
#  [('Croatian', 'JJ', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('Ms.', 'NNP', 'B-per')],
#  [('Croatia', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('ETA', 'NNP', 'B-org')],
#  [('That', 'DT', 'O')],
#  [('Pacific', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('At', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('As', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Although', 'IN', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('Two', 'CD', 'B-tim')],
#  [('Since', 'IN', 'O')],
#  [('In', 'IN', 'O')],
#  [('Although', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Land', 'NNP', 'O')],
#  [('Subsistence', 'NN', 'O')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Economic', 'JJ', 'O')],
#  [('Suriname', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Trade', 'NNP', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Suriname', 'NNP', 'B-org')],
#  [('Carib', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Britain', 'NNP', 'B-geo')],
#  [('In', 'IN', 'O')],
#  [('In', 'IN', 'O')],
#  [('Full', 'NNP', 'O')],
#  [('Grenada', 'NNP', 'B-geo')],
#  [('Six', 'CD', 'B-tim')],
#  [('Free', 'JJ', 'O')],
#  [('The', 'DT', 'B-org')],
#  [('Hurricane', 'NNP', 'O')],
#  [('A', 'DT', 'O')],
#  [('He', 'PRP', 'O')],
#  [('As', 'IN', 'O')],
#  [('One', 'CD', 'O')],
#  [('Mercury', 'NNP', 'B-per')],
#  [('Israeli', 'JJ', 'B-gpe')],
#  [('Rami', 'NNP', 'B-per')],
#  [('Also', 'RB', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('Authorities', 'NNS', 'O')],
#  [('Witnesses', 'NNS', 'O')],
#  [('No', 'DT', 'O')],
#  [('Iraq', 'NNP', 'B-geo')],
#  [('Meanwhile', 'RB', 'O')],
#  [('Afghan', 'JJ', 'B-gpe')],
#  [('In', 'IN', 'O')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Four', 'CD', 'O')],
#  [('Two', 'CD', 'O')],
#  [('When', 'WRB', 'O')],
#  [('But', 'CC', 'O')],
#  [('Primimoda', 'NNP', 'B-geo')],
#  [('Ndimyake', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Much', 'NN', 'O')],
#  [('That', 'DT', 'O')],
#  [('However', 'RB', 'O')],
#  [('Intel', 'NNP', 'B-org')],
#  [('Intel', 'NNP', 'B-org')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('At', 'IN', 'O')],
#  [('Local', 'JJ', 'O')],
#  [('Police', 'NNS', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Al-Mansoorain', 'NNP', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('It', 'PRP', 'O')],
#  [('Mission', 'NNP', 'O')],
#  [('It', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('SMART-1', 'NNP', 'O')],
#  [('SMART', 'NNP', 'O')],
#  [('The', 'DT', 'O')],
#  [('Witnesses', 'NNS', 'O')],
#  [('Abdikadir', 'NNP', 'B-per')],
#  [('Reuters', 'NNP', 'B-org')],
#  [('There', 'EX', 'O')],
#  [('Attacks', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('U.S.', 'NNP', 'B-geo')],
#  [('Independent', 'NNP', 'O')],
#  [('Lieberman', 'NNP', 'B-per')],
#  [('McCain', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('More', 'JJR', 'O')],
#  [('Cambodian', 'JJ', 'B-gpe')],
#  [('Former', 'JJ', 'O')],
#  [('Most', 'JJS', 'O')],
#  [('Cambodian', 'JJ', 'B-gpe')],
#  [('It', 'PRP', 'O')],
#  [('Five', 'CD', 'O')],
#  [('Following', 'VBG', 'O')],
#  [('Dignitaries', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('First', 'RB', 'O')],
#  [('It', 'PRP', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Similarly', 'RB', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Sudanese', 'JJ', 'B-gpe')],
#  [('Sudan', 'NNP', 'B-geo')],
#  [('More', 'JJR', 'B-tim')],
#  [('Haiti', 'NNP', 'B-geo')],
#  [('Officials', 'NNS', 'O')],
#  [('Bernard', 'NNP', 'B-per')],
#  [('Preval', 'NNP', 'B-per')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Palestinian', 'JJ', 'B-gpe')],
#  [('Authorities', 'NNS', 'O')],
#  [('Local', 'JJ', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Bangladesh', 'NNP', 'B-geo')],
#  [('Boat', 'NNP', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Wilma', 'NNP', 'B-per')],
#  [('At', 'IN', 'O')],
#  [('In', 'IN', 'O')],
#  [('The', 'DT', 'O')],
#  [('Long-range', 'JJ', 'O')],
#  [('Several', 'JJ', 'O')],
#  [('Sri', 'NNP', 'B-per')],
#  [('Officials', 'NNS', 'O')],
#  [('In', 'IN', 'O')],
#  [('A', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Sri', 'NNP', 'B-per')],
#  [('He', 'PRP', 'O')],
#  [('Forensic', 'JJ', 'O')],
#  [('An', 'DT', 'O')],
#  [('He', 'PRP', 'O')],
#  [('The', 'DT', 'O')],
#  [('United', 'NNP', 'B-org')],
#  [('More', 'JJR', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Officials', 'NNS', 'O')],
#  [('Authorities', 'NNS', 'O')],
#  [('Kashmiri', 'JJ', 'B-gpe')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Iran', 'NNP', 'B-geo')],
#  [('Speaking', 'VBG', 'O')],
#  [('Moscow', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('Meanwhile', 'RB', 'O')],
#  [('President', 'NNP', 'B-per')],
#  [('But', 'CC', 'O')],
#  [('President', 'NNP', 'B-per')],
#  [('In', 'IN', 'O')],
#  [('Hamas', 'NNP', 'B-org')],
#  [('Eid', 'NNP', 'B-geo')],
#  [('According', 'VBG', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Lawmakers', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('All', 'DT', 'O')],
#  [('Advocates', 'NNS', 'O')],
#  [('Hamas', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('U.N.', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('He', 'PRP', 'O')],
#  [('While', 'IN', 'O')],
#  [('His', 'PRP$', 'O')],
#  [('An', 'DT', 'O')],
#  [('Paul', 'NNP', 'B-per')],
#  [('U.S.', 'NNP', 'B-org')],
#  [('U.S.', 'NNP', 'B-org')],
#  [('European', 'NNP', 'B-per')],
#  [('Embedded', 'JJ', 'O')],
#  [('Videotape', 'NN', 'O')],
#  [('Several', 'DT', 'O')],
#  [('U.S.', 'NNP', 'B-gpe')],
#  [('The', 'DT', 'O')],
#  [('A', 'DT', 'O')],
#  [('One', 'CD', 'O')],
#  [('The', 'DT', 'O')],
#  [('There', 'EX', 'O')],
#  [('Hundreds', 'NNS', 'O')],
#  [('The', 'DT', 'O')],
#  [('Former', 'JJ', 'O')],
#  [('Reuters', 'NNP', 'B-org')],
#  [('A', 'DT', 'O')],
#  [('Last', 'JJ', 'O')],
#  [('They', 'PRP', 'O')],
#  [('India', 'NNP', 'B-geo')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Victims', 'NNS', 'O')],
#  [('Those', 'DT', 'O')],
#  [('The', 'DT', 'O')],
#  [('Barghouti', 'NNP', 'B-per')],
#  [('Fatah', 'NNP', 'B-org')],
#  [('The', 'DT', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('Israel', 'NNP', 'B-geo')],
#  [('A', 'DT', 'O')],
#  [('Syria', 'NNP', 'B-geo')],
#  [('In', 'IN', 'O')],
#  [('Mr.', 'NNP', 'B-per')],
#  [('The', 'DT', 'O')],
#  [('He', 'PRP', 'O')],
#  [('Talks', 'NNS', 'O')],
#  [('Syria', 'NNP', 'B-geo')],
#  [('Israel', 'NNP', 'B-geo')],
#  [('Military', 'JJ', 'O')],
#  [('The', 'DT', 'O')],
#  [('Earlier', 'RB', 'O')],
#  [('Clashes', 'NNS', 'O')],
#  ...]

# %% [markdown]
# ## Conversion of words and tags

# %%
# Convert words and tags into numbers
wordvec = {w : i for i , w in enumerate(words)}
tagvec = {t : i for i, t  in enumerate(tags)}

# %%
wordvec
# Out:
# {'resolved': 0,
#  'U.N.-protected': 1,
#  'Terry': 2,
#  'popular': 3,
#  'reconstruct': 4,
#  'colder-than-usual': 5,
#  'Jutarnji': 6,
#  'Monkey': 7,
#  'vents': 8,
#  'Cloud': 9,
#  'mosquito': 10,
#  'reopens': 11,
#  'disrupting': 12,
#  'Istanbul': 13,
#  'consulted': 14,
#  'Daughter': 15,
#  'seems': 16,
#  'Ventures': 17,
#  'Vavuniya': 18,
#  '3,348': 19,
#  'Angolan': 20,
#  'Volcanic': 21,
#  '300-million-dollar': 22,
#  '159': 23,
#  'desire': 24,
#  'Gachechiladze': 25,
#  'caved': 26,
#  'conference': 27,
#  'soil': 28,
#  'reputation': 29,
#  'bind': 30,
#  'Reduction': 31,
#  'cyber': 32,
#  'Envoy': 33,
#  'Bernard': 34,
#  'serpent': 35,
#  'suppliers': 36,
#  'oxygen': 37,
#  'practicing': 38,
#  'isolation': 39,
#  'big': 40,
#  'chapel': 41,
#  'eChoupal': 42,
#  'Mattoo': 43,
#  '60-kilometer': 44,
#  'mid-to-late': 45,
#  'Yushu': 46,
#  'neon': 47,
#  'exchange-rate': 48,
#  'Chaib': 49,
#  'mimics': 50,
#  'narrated': 51,
#  'applicants': 52,
#  'inconvenient': 53,
#  'Many': 54,
#  'Srinigar': 55,
#  'inefficiencies': 56,
#  'student-led': 57,
#  'notable': 58,
#  'headlines': 59,
#  'Boedihardjo': 60,
#  'IRAQ-POVERTY': 61,
#  'Patience': 62,
#  'actor-turned-musician': 63,
#  'Schearf': 64,
#  'Manipur': 65,
#  'well-developed': 66,
#  'Busta': 67,
#  'softer': 68,
#  'wheel': 69,
#  'Antwerp': 70,
#  'Ehud': 71,
#  'boat': 72,
#  'two-man': 73,
#  'geothermal': 74,
#  'Abdalla': 75,
#  'unaffiliated': 76,
#  'NAM': 77,
#  'Qaida-linked': 78,
#  'clinching': 79,
#  'sheeting': 80,
#  'Hydrographic': 81,
#  'el-Zahraa': 82,
#  'Guardsmen': 83,
#  'Challengerspace': 84,
#  'slowed': 85,
#  'aggravated': 86,
#  'sunk': 87,
#  '130-thousand': 88,
#  'Belet': 89,
#  'Hazem': 90,
#  'Endeavouron': 91,
#  'stampede': 92,
#  'escalated': 93,
#  'A&M': 94,
#  'manipulated': 95,
#  'cathedral': 96,
#  'whereby': 97,
#  'rice-growing': 98,
#  'militarist': 99,
#  'Gael': 100,
#  'clamor': 101,
#  'packaging': 102,
#  'dispose': 103,
#  'burying': 104,
#  '2018': 105,
#  'Railroad': 106,
#  '1500s': 107,
#  'Seiken': 108,
#  'Abu': 109,
#  'Occasional': 110,
#  'poses': 111,
#  'Sudeten': 112,
#  'remedy': 113,
#  'welfare-dependent': 114,
#  'inconsistent': 115,
#  '1,600': 116,
#  'Georgy': 117,
#  'politically-motivated': 118,
#  'demographer': 119,
#  'double-bombing': 120,
#  'enact': 121,
#  'H': 122,
#  'unconsciousness': 123,
#  'granddaughter': 124,
#  'jailings': 125,
#  'McAuliffe': 126,
#  'Moqtada': 127,
#  'Miyazaki': 128,
#  'Bernanke': 129,
#  'Inauguration': 130,
#  'treat': 131,
#  'extolling': 132,
#  '2022': 133,
#  'authenticate': 134,
#  'biennial': 135,
#  'Coordinating': 136,
#  'mention': 137,
#  'certify': 138,
#  'Grimmette': 139,
#  'biologist': 140,
#  'Reader': 141,
#  'Nicolae': 142,
#  'finishing': 143,
#  'Stem': 144,
#  'Bursting': 145,
#  'Lak': 146,
#  'U.S.-Russian': 147,
#  'staffing': 148,
#  'guards': 149,
#  'diplomats': 150,
#  'Tzipi': 151,
#  'hard-line': 152,
#  'Amrullah': 153,
#  'Resting': 154,
#  'publicly': 155,
#  'group': 156,
#  'Preparations': 157,
#  'quake-stricken': 158,
#  'siege': 159,
#  'Longer-term': 160,
#  'razor': 161,
#  'Vavi': 162,
#  'fourth-busiest': 163,
#  'ex-girlfriend': 164,
#  'Resistance': 165,
#  'continuation': 166,
#  'S&P': 167,
#  'picked': 168,
#  '65': 169,
#  'squad': 170,
#  'agreements': 171,
#  'acknowledged': 172,
#  'Jing': 173,
#  'Nabeel': 174,
#  'Annan': 175,
#  'pre-paid': 176,
#  'Diplomacy': 177,
#  'helmets': 178,
#  'Explosive': 179,
#  'Dakar': 180,
#  'SAMBI': 181,
#  'Osnabrueck': 182,
#  'Chirac': 183,
#  'ESTRADA': 184,
#  'ex-president': 185,
#  'Flanders': 186,
#  'Taj': 187,
#  'temporarily': 188,
#  'Statoil': 189,
#  'impassable': 190,
#  'governors': 191,
#  'Hofstad': 192,
#  'Warsaw': 193,
#  'Kian': 194,
#  'touts': 195,
#  'appreciate': 196,
#  'Shota': 197,
#  'emission': 198,
#  'tourism-driven': 199,
#  'one-child': 200,
#  'out': 201,
#  'mbalax': 202,
#  'accommodations': 203,
#  'Kirkuk': 204,
#  'Libyan': 205,
#  'Al-Anbar': 206,
#  '137': 207,
#  'Mouknass': 208,
#  'sums': 209,
#  'Lakshman': 210,
#  'Gibbs': 211,
#  'Zvarych': 212,
#  'inhabitants': 213,
#  '6,10,000': 214,
#  'rites': 215,
#  'celestial': 216,
#  'colonize': 217,
#  'PIGEON': 218,
#  'alarming': 219,
#  'fatwa': 220,
#  'Panmunjom': 221,
#  'apparent': 222,
#  'peasants': 223,
#  'Bangladeshis': 224,
#  'Bangalore': 225,
#  'sacred': 226,
#  "Ba'th": 227,
#  'with': 228,
#  'Nearby': 229,
#  'Drinan': 230,
#  'Farraj': 231,
#  'Industries': 232,
#  'Eduardo': 233,
#  're-invested': 234,
#  'dose': 235,
#  'Search': 236,
#  'Hailu': 237,
#  'URIBE': 238,
#  'males': 239,
#  'obligates': 240,
#  'Narsingh': 241,
#  'Ayodhya': 242,
#  'hidden': 243,
#  'Kirk': 244,
#  'Saddamists': 245,
#  'serenaded': 246,
#  'mid-20th': 247,
#  'mishandling': 248,
#  'Shamsbari': 249,
#  'rushed': 250,
#  'Jihad': 251,
#  '220-kilogram': 252,
#  'stranger': 253,
#  'several': 254,
#  'Ferrero': 255,
#  'Fund-Global': 256,
#  'dismissing': 257,
#  'Basayev': 258,
#  'expired': 259,
#  'intuitive': 260,
#  'antics': 261,
#  'Kwazulu-Natal': 262,
#  'cote': 263,
#  'il': 264,
#  'Salas': 265,
#  'minimize': 266,
#  'force': 267,
#  'centrally-planned': 268,
#  'College': 269,
#  'Biak': 270,
#  'Arts': 271,
#  'humiliation': 272,
#  'Partridges': 273,
#  'four-million': 274,
#  'Venice': 275,
#  'CORREA': 276,
#  'Oumar': 277,
#  '522': 278,
#  'flooding': 279,
#  'Fox': 280,
#  'Comoros': 281,
#  'dusk': 282,
#  'fill': 283,
#  'Afghanis': 284,
#  'greatly': 285,
#  'invested': 286,
#  'repealed': 287,
#  'recognizing': 288,
#  'Messages': 289,
#  'varies': 290,
#  'Lahore': 291,
#  'headlights': 292,
#  'raiding': 293,
#  'Namibian': 294,
#  'Coldplay': 295,
#  'fine-tuning': 296,
#  'Gregg': 297,
#  'MacKay': 298,
#  'State-designate': 299,
#  '1609': 300,
#  'spirit': 301,
#  'energetic': 302,
#  'disinformation': 303,
#  'Toure': 304,
#  'McCartney': 305,
#  'nationalize': 306,
#  "N'Zerekore": 307,
#  'defection': 308,
#  'Posht-e-Rud': 309,
#  'Post': 310,
#  'Cavalese': 311,
#  'remnants': 312,
#  'Construction': 313,
#  'Six-country': 314,
#  'insidious': 315,
#  'Duluth': 316,
#  'rides': 317,
#  'fenced': 318,
#  'jobless': 319,
#  "Pe'at": 320,
#  'Takhar': 321,
#  'Am': 322,
#  'Otunbayeva': 323,
#  'Wolde-Michael': 324,
#  'Dawei-Ye': 325,
#  'scold': 326,
#  'Shihab': 327,
#  'shores': 328,
#  '02-Jun': 329,
#  'Quarter': 330,
#  'Creator': 331,
#  'stumbled': 332,
#  'disrepair': 333,
#  'Suspected': 334,
#  '8.8-magnitude': 335,
#  'cohesion': 336,
#  'encounters': 337,
#  'senator': 338,
#  'accurate': 339,
#  'decathlon': 340,
#  'Caribbean': 341,
#  'Persson': 342,
#  'four-decade': 343,
#  'serve': 344,
#  'pence': 345,
#  'newly-formed': 346,
#  'Horizonte': 347,
#  'organic': 348,
#  'disbursement': 349,
#  'exacted': 350,
#  'underwent': 351,
#  'Jericho': 352,
#  'Blackwater': 353,
#  'Kofi': 354,
#  'hectares': 355,
#  'Ongoing': 356,
#  'terminate': 357,
#  'charming': 358,
#  'asylum': 359,
#  'altitude': 360,
#  'Abdel-Rahman': 361,
#  'Tarmohammed': 362,
#  'aggressively': 363,
#  'Herzegovina': 364,
#  'embolden': 365,
#  'Queen': 366,
#  'Al-Jazeera': 367,
#  'thought': 368,
#  'bag': 369,
#  'participated': 370,
#  'reassured': 371,
#  'camouflage': 372,
#  'al-Tamimi': 373,
#  'unimaginable': 374,
#  'licensing': 375,
#  'Malaysian-led': 376,
#  'afforded': 377,
#  '22.4': 378,
#  'Week': 379,
#  'Bolt': 380,
#  'Eindhoven': 381,
#  'SAVIMBI': 382,
#  'Mangwana': 383,
#  'Chacon': 384,
#  '170': 385,
#  'Ranch': 386,
#  'Mwai': 387,
#  'murderers': 388,
#  'Yurchikhin': 389,
#  'Nikolas': 390,
#  'narrowing': 391,
#  'Town': 392,
#  'Serra': 393,
#  'arteries': 394,
#  'non-functional': 395,
#  'below-average': 396,
#  'acrobatic': 397,
#  'Svinarov': 398,
#  'customs': 399,
#  'prayed': 400,
#  'aided': 401,
#  'Milan': 402,
#  'editor-in-chief': 403,
#  'Ul-Islam': 404,
#  'Coffee': 405,
#  'submitting': 406,
#  'affiliated': 407,
#  'anchor': 408,
#  'Samho': 409,
#  'cancer': 410,
#  'refloating': 411,
#  '915': 412,
#  'Alaska': 413,
#  'insistence': 414,
#  'Hycamtin': 415,
#  '9.625': 416,
#  'Arthurs': 417,
#  'Scheduled': 418,
#  'al-Youm': 419,
#  'avenging': 420,
#  'inconclusive': 421,
#  'wonder': 422,
#  'Interahamwe': 423,
#  'Soviet-sponsored': 424,
#  'prosecuted': 425,
#  '20-meter': 426,
#  'Liege': 427,
#  'Sylvester': 428,
#  'Yalcinkaya': 429,
#  'nullify': 430,
#  '191': 431,
#  'civilian': 432,
#  '01-Jan': 433,
#  'Greens': 434,
#  'Ranger': 435,
#  'treasures': 436,
#  'Prithvi': 437,
#  'bases': 438,
#  'establishes': 439,
#  'Parkinson': 440,
#  'Uzair': 441,
#  'tension': 442,
#  'winner': 443,
#  '46-nation': 444,
#  'Ford': 445,
#  '720': 446,
#  'whatever': 447,
#  'Sarna': 448,
#  'wrongfully': 449,
#  '&': 450,
#  'TRYGGVASON': 451,
#  'outlining': 452,
#  'tarnished': 453,
#  'credentials': 454,
#  'thirty': 455,
#  'Barbey': 456,
#  '1,254': 457,
#  'Economics': 458,
#  'abusive': 459,
#  'defaulted': 460,
#  'accepts': 461,
#  'toothless': 462,
#  'skyscraper': 463,
#  'Hanun': 464,
#  'canned': 465,
#  'southwest': 466,
#  'Kurzban': 467,
#  'responsibly': 468,
#  'unmonitored': 469,
#  'Soldaten': 470,
#  'premises': 471,
#  'indicating': 472,
#  '1930s': 473,
#  'Seyoum': 474,
#  'policy': 475,
#  'carries': 476,
#  'Pro-Russian': 477,
#  'explorers': 478,
#  'meningitis': 479,
#  'Verde': 480,
#  'Kenneth': 481,
#  'strikingly': 482,
#  'mauled': 483,
#  'stoning': 484,
#  'joined': 485,
#  'wiped': 486,
#  'unfunded': 487,
#  'rarely': 488,
#  '28.25': 489,
#  'suicide-bomber': 490,
#  'Rescuers': 491,
#  'students': 492,
#  'avarice': 493,
#  'Kimi': 494,
#  'classified': 495,
#  'patents': 496,
#  'Afars': 497,
#  'contacting': 498,
#  'counterproductive': 499,
#  'Adding': 500,
#  'riot': 501,
#  'unwavering': 502,
#  'eight-year-old': 503,
#  'Mashjid': 504,
#  'transports': 505,
#  'Gong': 506,
#  'outsourcing': 507,
#  'Europe-wide': 508,
#  'corrected': 509,
#  'Khaisor': 510,
#  'difficulties': 511,
#  'siphoning': 512,
#  'habitations': 513,
#  'necks': 514,
#  'conglomerate': 515,
#  'applies': 516,
#  'insisting': 517,
#  'Islam': 518,
#  'mid-December': 519,
#  'lambasted': 520,
#  'Exiles': 521,
#  'impede': 522,
#  '259': 523,
#  'improved': 524,
#  'Tikrit': 525,
#  'ARISTIDE': 526,
#  'corrosion': 527,
#  'above': 528,
#  'Flemings': 529,
#  'transitioning': 530,
#  'immensely': 531,
#  'black-clad': 532,
#  'Viktor': 533,
#  'Nicholas': 534,
#  'Drops': 535,
#  'repatriation': 536,
#  'BBC': 537,
#  'Self-Defense': 538,
#  'bias': 539,
#  'Basra': 540,
#  'reversal': 541,
#  'Miltzow': 542,
#  '367': 543,
#  'Schlegel': 544,
#  'auditing': 545,
#  'Sindh': 546,
#  'Rechnitzer': 547,
#  'militarily': 548,
#  'Committee': 549,
#  'Mohannad': 550,
#  'administering': 551,
#  'arriving': 552,
#  'Damascus': 553,
#  'Rish': 554,
#  'Abdel': 555,
#  'worm': 556,
#  'Egypt-Gaza': 557,
#  'director-general': 558,
#  'tenure': 559,
#  "O'Hare": 560,
#  'Chuprun': 561,
#  'safer': 562,
#  'Apr-46': 563,
#  'stray': 564,
#  '?': 565,
#  'photograph': 566,
#  'Settled': 567,
#  'Strategic': 568,
#  'Stockholm': 569,
#  'Lukic': 570,
#  'PODEMOS': 571,
#  'paces': 572,
#  'Gun': 573,
#  'Ruhollah': 574,
#  '90-year-old': 575,
#  'hurled': 576,
#  'lose': 577,
#  '1,59,000': 578,
#  'Nigerians': 579,
#  'al-Hayam': 580,
#  'suite': 581,
#  'Koreb': 582,
#  'seminary': 583,
#  'applauding': 584,
#  'Raich': 585,
#  'scruple': 586,
#  'Telecom': 587,
#  'cafes': 588,
#  'mansion': 589,
#  'Slavic': 590,
#  '122': 591,
#  'vagaries': 592,
#  'video-sharing': 593,
#  'license': 594,
#  'Burton': 595,
#  '1278': 596,
#  'Dragoljub': 597,
#  'Telesur': 598,
#  'debts': 599,
#  'suffocated': 600,
#  'admiration': 601,
#  'curtains': 602,
#  'Monaco': 603,
#  'Sinai': 604,
#  'TRAVELERS': 605,
#  'arsenals': 606,
#  'slightest': 607,
#  'pets': 608,
#  'pulled': 609,
#  'graveyards': 610,
#  'standard-of-living': 611,
#  'Obrador': 612,
#  'carrier': 613,
#  'Made': 614,
#  'Verizon': 615,
#  'Budny': 616,
#  'Austrian': 617,
#  'vaccinators': 618,
#  'limbs': 619,
#  'stump': 620,
#  'Dubbed': 621,
#  'gala': 622,
#  'oppressed': 623,
#  'Napolitano': 624,
#  'Kor': 625,
#  'supervising': 626,
#  'Gas': 627,
#  'provided': 628,
#  'multiply': 629,
#  'Polish-Lithuanian': 630,
#  'assailants': 631,
#  'convention': 632,
#  'Huda': 633,
#  'accessed': 634,
#  'nozzles': 635,
#  'plane': 636,
#  'Guangzhong': 637,
#  'Silvestre': 638,
#  'Tabare': 639,
#  'goodwill': 640,
#  'gaining': 641,
#  'Homeowners': 642,
#  'quarterly': 643,
#  'toxicology': 644,
#  'Kartli-Iberia': 645,
#  'opened': 646,
#  'Bids': 647,
#  'reaped': 648,
#  'rowing': 649,
#  'GDP': 650,
#  'bioethics': 651,
#  'Garrigues': 652,
#  'Sandy': 653,
#  'Alizai': 654,
#  'sulphur': 655,
#  'Edwards': 656,
#  '461': 657,
#  '225': 658,
#  'Na': 659,
#  'codefendants': 660,
#  'forecasters': 661,
#  'Kenya': 662,
#  'fourth-highest': 663,
#  'Delgado': 664,
#  'highest': 665,
#  'occupy': 666,
#  'weaker': 667,
#  'Yanbu': 668,
#  'cheeks': 669,
#  'divorcing': 670,
#  "N'Dour": 671,
#  'Cargo': 672,
#  'cooperation': 673,
#  'peace-loving': 674,
#  'Lion': 675,
#  '4.55': 676,
#  'Reid': 677,
#  'starred': 678,
#  'Christine': 679,
#  'Safeguards': 680,
#  'facing': 681,
#  'rift': 682,
#  'Retail': 683,
#  'justice': 684,
#  'Rowan': 685,
#  'insurmountable': 686,
#  '04-Jan': 687,
#  'surrounding': 688,
#  'jute': 689,
#  'mockery': 690,
#  'Iscuande': 691,
#  'Daniele': 692,
#  'shoreline': 693,
#  'anti-flu': 694,
#  'drawings': 695,
#  'Southern': 696,
#  'grow': 697,
#  'Saleh': 698,
#  'meet': 699,
#  'Destiny': 700,
#  'Borjomi': 701,
#  'Ahronoth': 702,
#  'retained': 703,
#  'farfetched': 704,
#  'front-page': 705,
#  'Bajur': 706,
#  'faltering': 707,
#  'weight-loss': 708,
#  'contracts': 709,
#  'Regiment': 710,
#  'Scorpion': 711,
#  'disparities': 712,
#  '598-seat': 713,
#  'theatergoers': 714,
#  'necessitate': 715,
#  'Paynesville': 716,
#  'fast-food': 717,
#  'lest': 718,
#  'blindfolded': 719,
#  'museums': 720,
#  'portfolio': 721,
#  'half': 722,
#  '73,276': 723,
#  'conductor': 724,
#  'bouncing': 725,
#  'Kouk': 726,
#  'epidemiologists': 727,
#  'interception': 728,
#  'combining': 729,
#  'Eritrea-Ethiopia': 730,
#  'jersey': 731,
#  'barge': 732,
#  'strive': 733,
#  'forestry': 734,
#  'Iraq': 735,
#  'Mehran': 736,
#  'Gazprom': 737,
#  'intensifying': 738,
#  'lamented': 739,
#  'auditors': 740,
#  'Solis': 741,
#  'necessities': 742,
#  'USPI': 743,
#  'consecutive': 744,
#  'Malwiya': 745,
#  'cassettes': 746,
#  'uninsured': 747,
#  'embedded': 748,
#  'Ayyub': 749,
#  'Mehlis': 750,
#  'meets': 751,
#  'News': 752,
#  'stoves': 753,
#  'Andry': 754,
#  'Guard': 755,
#  'possible': 756,
#  'negotiator': 757,
#  'Cameroon': 758,
#  'reductions': 759,
#  'Sakhalin-2': 760,
#  'zoological': 761,
#  'Dogg': 762,
#  '370': 763,
#  'militant-related': 764,
#  'Fargo': 765,
#  'parties': 766,
#  'Poroshenko': 767,
#  'R�sch': 768,
#  'worries': 769,
#  'jailhouse': 770,
#  'Leif': 771,
#  'Weddings': 772,
#  'jog': 773,
#  'informal': 774,
#  'rid': 775,
#  'skip': 776,
#  'Afghani': 777,
#  '4,10,000': 778,
#  'Dizzy': 779,
#  'Khaled': 780,
#  'Nazran': 781,
#  'unlawful': 782,
#  'densely-populated': 783,
#  'interviewer': 784,
#  'bomb-proof': 785,
#  'VanAllen': 786,
#  'strategic': 787,
#  'Frenchmen': 788,
#  'Ana': 789,
#  'Founding': 790,
#  'ideal': 791,
#  'replaced': 792,
#  'Datapoint': 793,
#  'controlled': 794,
#  'Christians': 795,
#  'Hispaniola': 796,
#  'natives': 797,
#  'ignore': 798,
#  'Mainz': 799,
#  'Rebecca': 800,
#  'CRANES': 801,
#  'compliments': 802,
#  'capitalist': 803,
#  'transition': 804,
#  'generals': 805,
#  'frequencies': 806,
#  'al-Qawasmi': 807,
#  'shrinks': 808,
#  'activity': 809,
#  'masterminding': 810,
#  'tanker': 811,
#  '11725': 812,
#  'talked': 813,
#  'random': 814,
#  'meanwhile': 815,
#  'lottery': 816,
#  'statments': 817,
#  'Novakatkan': 818,
#  'equalized': 819,
#  'Bengal': 820,
#  'Surgeon': 821,
#  'ecotourism': 822,
#  '690': 823,
#  'matched': 824,
#  'penetrate': 825,
#  'authenticity': 826,
#  '243': 827,
#  'Tomb': 828,
#  'HARES': 829,
#  'dependency': 830,
#  'Lusaka': 831,
#  'Kohlschreiber': 832,
#  'Sgorbati': 833,
#  'Wiig': 834,
#  'burned': 835,
#  'draws': 836,
#  'forensic': 837,
#  'Splendour': 838,
#  'al-Aqsa': 839,
#  '68.4': 840,
#  'Indian-': 841,
#  'Heinz': 842,
#  'Tytler': 843,
#  'edict': 844,
#  'withered': 845,
#  'Orenburg': 846,
#  'inciting': 847,
#  'peril': 848,
#  'cylinders': 849,
#  'handling': 850,
#  'White': 851,
#  'insulation': 852,
#  'Ezzedin': 853,
#  'spiraled': 854,
#  'Producing': 855,
#  'consular': 856,
#  'Five': 857,
#  'nullified': 858,
#  'Sharon': 859,
#  'opening-day': 860,
#  'Walleye': 861,
#  'knight': 862,
#  'Chancellor': 863,
#  'DC': 864,
#  'unknowingly': 865,
#  'fears': 866,
#  'Sassou-Nguesso': 867,
#  'nasal': 868,
#  'U.S.-Iraqi': 869,
#  'literate': 870,
#  'Manmohan': 871,
#  'Stubb': 872,
#  'ambassador-at-large': 873,
#  'directed': 874,
#  'sees': 875,
#  'weather': 876,
#  'privilege': 877,
#  'sprayed': 878,
#  'rallying': 879,
#  'Jersey': 880,
#  'depleting': 881,
#  'dubious': 882,
#  'rabbis': 883,
#  'NATO-Afghan': 884,
#  'haves': 885,
#  'Wise': 886,
#  '53-year': 887,
#  'Altria': 888,
#  'affiliations': 889,
#  'Bavarian': 890,
#  'Ashfaq': 891,
#  'wild-boar': 892,
#  'Vukovar': 893,
#  'pilgrims': 894,
#  'Mayer': 895,
#  'revere': 896,
#  'fundraising': 897,
#  'Finance': 898,
#  'Hilda': 899,
#  'Marta': 900,
#  'Ketzer': 901,
#  '215': 902,
#  'Clinic': 903,
#  'Years': 904,
#  'Comprehensive': 905,
#  'enterprising': 906,
#  'GM': 907,
#  '20th': 908,
#  'doused': 909,
#  'sunflower': 910,
#  'Terrorist': 911,
#  'Arap': 912,
#  'Horobets': 913,
#  'remainder': 914,
#  'uneven': 915,
#  'qualifiers': 916,
#  'Kveta': 917,
#  'mutating': 918,
#  'Baby': 919,
#  'DPRK': 920,
#  'orphan': 921,
#  'nationalized': 922,
#  'reefs': 923,
#  'two-part': 924,
#  'credible': 925,
#  'replenish': 926,
#  'colors': 927,
#  'accelerate': 928,
#  'Razuri': 929,
#  'wreck': 930,
#  'Moroccan': 931,
#  'Schwarzenburg': 932,
#  'Gunsmoke': 933,
#  'Pramoni': 934,
#  'Mostafavi': 935,
#  'Forty-one': 936,
#  'collaboration': 937,
#  'hopeful': 938,
#  'Aghazadeh': 939,
#  'conservationists': 940,
#  'sews': 941,
#  'reassuring': 942,
#  'Wagner': 943,
#  'Palestinian-Americans': 944,
#  'Franklin': 945,
#  'syphon': 946,
#  'Camilo': 947,
#  'ahead': 948,
#  'roams': 949,
#  'derive': 950,
#  'fatigues': 951,
#  'Musharraf': 952,
#  'covers': 953,
#  'doubt': 954,
#  '8000': 955,
#  '2.75': 956,
#  'jet': 957,
#  'Evgeni': 958,
#  'loudspeakers': 959,
#  'scheduled': 960,
#  'precinct': 961,
#  'el-Hadary': 962,
#  'incumbent': 963,
#  'shoved': 964,
#  'Ataturk': 965,
#  'sadly': 966,
#  'Rolling': 967,
#  'relate': 968,
#  'halfway': 969,
#  'Kountch�': 970,
#  'Greg': 971,
#  'Khursheed': 972,
#  'charcoal': 973,
#  'Marra': 974,
#  'airport': 975,
#  '5.7-kilometer': 976,
#  'peregrine': 977,
#  'master': 978,
#  'Doug': 979,
#  'tabloid': 980,
#  'Votel': 981,
#  'unbeaten': 982,
#  'Sufi': 983,
#  'anniversary': 984,
#  'Srebrenica': 985,
#  'adherence': 986,
#  'wildly': 987,
#  'candlelit': 988,
#  'website': 989,
#  'porpoises': 990,
#  'functioning': 991,
#  'being': 992,
#  'Shevardnadze': 993,
#  'subcontinent': 994,
#  'Preventive': 995,
#  'on': 996,
#  '9.9': 997,
#  '128-member': 998,
#  'Tufail': 999,
#  ...}

# %%
tagvec
# Out:
# {'VBZ': 0,
#  'VB': 1,
#  'WP': 2,
#  'JJ': 3,
#  ';': 4,
#  'NNS': 5,
#  'WRB': 6,
#  'VBP': 7,
#  'EX': 8,
#  ',': 9,
#  'RRB': 10,
#  'FW': 11,
#  'RBS': 12,
#  'WDT': 13,
#  'RBR': 14,
#  'JJS': 15,
#  'MD': 16,
#  'UH': 17,
#  'PDT': 18,
#  'NNP': 19,
#  'PRP': 20,
#  'CC': 21,
#  'CD': 22,
#  'JJR': 23,
#  'RP': 24,
#  'NNPS': 25,
#  '.': 26,
#  ':': 27,
#  'VBG': 28,
#  'RB': 29,
#  'LRB': 30,
#  'VBN': 31,
#  'NN': 32,
#  'WP$': 33,
#  'TO': 34,
#  'IN': 35,
#  'POS': 36,
#  'DT': 37,
#  'PRP$': 38,
#  'VBD': 39,
#  '``': 40,
#  '$': 41}

# %% [markdown]
# ## Prepare input and output data

# %%
from keras.preprocessing.sequence import pad_sequences

from keras.preprocessing.sequence import pad_sequences
max_len = 50
X = [[wordvec[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=len(words)-1)
y = [[tagvec[w[1]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tagvec["."])

# %%
X.shape
# Out:
# (47959, 50)

# %%
y.shape
# Out:
# (47959, 50)

# %%
print(len(y))
# Out:
# 47959

# %%
len(tags)
# Out:
# 42

# %% [markdown]
# ##  Conversion of  output to one-hot bit

# %%
from tensorflow.keras.utils import to_categorical
y = [to_categorical(i, num_classes = len(tags) )for i in y]

# %%
len(y)
# Out:
# 47959

# %% [markdown]
# ## Training and Testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y , test_size=0.20)

# %%
len(X_train)
# Out:
# 38367

# %%
len(y_train)
# Out:
# 38367

# %%
import tensorflow  as tf
from tensorflow import keras

# %%
X.shape[1]
# Out:
# 50

# %%
model = keras.Sequential([
    keras.layers.Embedding(input_dim = len(words), output_dim = 50, input_length = X.shape[1]),
    keras.layers.Dropout(0.1),
    keras.layers.Bidirectional(keras.layers.LSTM(X.shape[1], return_sequences = True , recurrent_dropout = 0.2)),
    keras.layers.TimeDistributed(keras.layers.Dense(len(tags), activation = 'softmax'))
])

# %%
model.compile(optimizer="rmsprop",loss="categorical_crossentropy", metrics = ['accuracy'])

# %%
#y_train = tf.stack(y_train)
#X_train = tf.stack(X_train)

# %%
model.fit(X_train, np.array(y_train) , epochs = 3)
# Out:
# Epoch 1/3
# 1199/1199 [==============================] - 77s 59ms/step - loss: 0.0446 - accuracy: 0.9935
# Epoch 2/3
# 1199/1199 [==============================] - 72s 60ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 3/3
# 1199/1199 [==============================] - 72s 60ms/step - loss: 0.0036 - accuracy: 0.9990

# %% [markdown]
# ## Demo Test

# %%
# Demo test on one sample. 

i= 1213 # Some test sentence sample
p = model.predict(np.array([X_test[i]]))
p = np.argmax(p, axis =-1)# Map softmax back to a POS index

for i, (w, pred) in enumerate(zip(X_test[i], p[0])): # for every word in the sentence
    print("{:40} -- {}".format(words[w], tags[pred])) # Print word and tag
    if pred == 43 and p[0][i+1] == 43:
        break
# Out:
# He                                       -- PRP
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
# dummy                                    -- .
